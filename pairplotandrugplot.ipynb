# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns 
import warnings
# %matplotlib inline 

r=pd.read_csv("Financial Sample.csv")

sns.pairplot(r,palette="Reds")

# %%
#Sayısal değeri olan sütunda ki verileri birbiri ile kıyaslar.

sns.pairplot(r,hue="Year",palette="inferno")

# %%
sns.rugplot(r["Year"],color="r",height=0.8)

# %%
sns.rugplot(r["Year"],color="r",height=0.4)
sns.kdeplot(r["Units Sold"],color="y",)
