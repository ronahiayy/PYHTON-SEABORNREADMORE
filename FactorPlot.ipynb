# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns 
import warnings
# %matplotlib inline 

veri=pd.read_csv("Financial Sample.csv")
veri

#Factorplot içerisinde bulunan kind fonksiyonu sayesinde diğer Plotlar ile birlikte kullanılır.

import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns 
import warnings
# %matplotlib inline 

veri=pd.read_csv("Financial Sample.csv")
veri
# Out:
#         Segment                   Country     Product   Discount Band   \
# 0    Government  United States of America       Paseo             Low
# 1    Government                    France    Amarilla            None
# 2    Government                   Germany        Velo             Low
# 3    Government                   Germany    Amarilla             Low
# 4    Government                   Germany        Velo             Low
# ..          ...                       ...          ...             ...
# 695  Enterprise  United States of America        Velo            High
# 696  Enterprise                    Mexico   Carretera            High
# 697  Enterprise  United States of America    Amarilla            High
# 698  Enterprise                   Germany   Carretera            High
# 699  Enterprise                    Canada         VTT            High
#
#      Units Sold Manufacturing Price Sale Price    Gross Sales   Discounts  \
# ...

# %%
sns.factorplot(x="Country",y="Month Number",data=veri,kind="swarm")
# Out:
# C:\Users\ronah\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x="Country",y="Month Number",data=veri,kind="violin")

# %%
sns.factorplot(x="Country",y="Month Number",data=veri,kind="point")
# Out:
# C:\Users\ronah\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x="Country",y="Month Number",data=veri,kind="point")
# Out:
# C:\Users\ronah\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x="Country",y="Month Number",data=veri,kind="bar")
# Out:
# C:\Users\ronah\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
